# %%
#Assignment:
#let’s merge this network: http://doi.org/10.18119/N91597
#    with this other one: http://www.ndexbio.org/#/network/1c69beff-1229-11e6-a039-06603eb7f303
#    or http://www.ndexbio.org/#/network/89975ebb-6294-11e7-a03e-0ac135e8bacf
#Merge them to make a new network in which nodes that have the same name are combined.
#If there is node 1 in network 1 that has the same name as node 2 in network 2, 
#    the new network should have just one node of that name that has all the attributes from node 1 AND node 2.
#As you do the merge, each node should be given an additional attribute “fromNetwork” 
#    so we can tell which network it originally came from. Values can be “network1”, “network2” or “both”
#Save to ndex
#Use Cytoscape to give it a graphic style in which the nodes are colored based on “fromNetwork”

#Steps:
#Step 1: for each node in TO, store the id as the value and the name as the key in the name-id map
#Step 2: for each node in FROM, check if its name is already in the name-id map. 
#        If it is, then store the TO id as the value and the from id as the key in the from-to-id-map. 
#        Otherwise, create the node in the TO network and 
#        then store the mapping between the node id in FROM to the id of the new node in TO.
#Step 3: copy the edges from FROM, 
#        creating new edges using the corresponding node ids in the from-to-node-id map and old_new_id_map.

#Special notice:
# Method "create_node" returns a new node id in To network, the index always begins from "0",
#   if the created id is duplicated with the existing id in the To network, the new node will replace the existing node.
#   Therefor, we should check the node id in both networks to decide which is the To network.
# Same as method 'create_edge'

# %%
import ndex2.client as nc
import io
import json
from time import sleep

from ndex2.nice_cx_network import NiceCXNetwork
import ndex2

import networkx as nx
import numpy as np

#create a NDEx client object to access my accouont on the NDEx server
my_account="Jeffreyc"
my_password="Frenchfri3"

my_ndex=nc.Ndex2("http://public.ndexbio.org", my_account, my_password)
my_ndex.update_status()

# %%
#get NiceCX objects in order to add attribute

uuid_1 = '98ba6a19-586e-11e7-8f50-0ac135e8bacf'
uuid_2 = '1c69beff-1229-11e6-a039-06603eb7f303'

#Smaller networks for testing
#uuid_1 = '6bde432c-0b40-11e7-aba2-0ac135e8bacf'
#uuid_2 = 'c53894ce-8e47-11e5-b435-06603eb7f303'

NiceCX_network_1 = ndex2.create_nice_cx_from_server(server='http://public.ndexbio.org',  uuid = uuid_1)
NiceCX_network_2 = ndex2.create_nice_cx_from_server(server='http://public.ndexbio.org',  uuid = uuid_2)

print ("\n")
NiceCX_network_1.print_summary()
print ("\n")
NiceCX_network_2.print_summary()
# Out:
# Name: BioPlex 2.0 ( ~ 56,000 interactions )
# Nodes: 10961
# Edges: 56553
# Node Attributes: 10961
# Edge Attributes: 169659
#
#
#
# Name: ChEMBL - High Affinity Compounds vs human targets (Commercially available)
# Nodes: 3564
# Edges: 11564
# Node Attributes: 13569
# Edge Attributes: 57820

# %%
#determine which network is "TO" and "FROM"

#nodes and edges in two networks may have duplicate id
#Duplicate large network to avoid the issue

#get the number of nodes in each network
number_of_nodes_network1 = len(NiceCX_network_1.get_nodes())
number_of_nodes_network2 = len(NiceCX_network_2.get_nodes())

#print(number_of_nodes_network1)
#print(number_of_nodes_network2)

#the smaller network is the From network
if(number_of_nodes_network1 >= number_of_nodes_network2):
    NiceCX_larger = NiceCX_network_1
    NiceCX_From = NiceCX_network_2
else:
    NiceCX_larger = NiceCX_network_2
    NiceCX_From = NiceCX_network_1
    
#copy the larger network to To network    
NiceCX_To = NiceCXNetwork() #Create an empty niceCx network
        
#copy the larger network to the new created network, the new network is To network
for node_id, larger_node in NiceCX_larger.get_nodes():
    #get each node name in larger network   
    name = list(larger_node.values())[1]  
            
    #'create_node' creates an empty node and returns a node id in the TO network 
    NiceCX_To.create_node(name,node_id)   
        
    #set the node attribute values    
    
    # CAUTION: some nodes in this network have no node attribute! 
    #          In that case, get_node_attributes(node_id) returns a "None" value
    node_attr_list = NiceCX_larger.get_node_attributes(node_id)     #return each node attrbute as an array
    
    if (node_attr_list != None):    
        for i in range(len(node_attr_list)): 
            node_attr_name = list(node_attr_list[i].values())[1]   #node_attributes[] is a dict with 3 pairs, keys() is an array['po','n','v'] 
            node_attr_value = list(node_attr_list[i].values())[2]
        
            NiceCX_To.set_node_attribute(node_id, node_attr_name, node_attr_value ) 
            
#copy the edges to To network

#create 3 lists to store each edge's 's', 't', 'i' values. These 3 list will be used for checking duplicate edges
to_edge_s_list = []
to_edge_t_list = []
to_edge_i_list = []

for edge_id, larger_edge in NiceCX_larger.get_edges():        
    edge_s = larger_edge.get('s') #source node id in larger network
    edge_t = larger_edge.get('t') #target node id in larger network
    edge_i = larger_edge.get('i') #interaction in the larger network
    
    to_edge_s_list.append(edge_s)
    to_edge_t_list.append(edge_t)
    to_edge_i_list.append(edge_i)

    # 'create_edge' creates an empty edge and returns an edge id
    NiceCX_To.create_edge(edge_s, edge_t, edge_i)

    #set the edge attribute values      
    edge_attr_list = NiceCX_larger.get_edge_attributes(edge_id)
    if(edge_attr_list != None):
        for j in range(len(edge_attr_list)): 
            edge_attr_name = list(edge_attr_list[j].values())[1]   
            edge_attr_value = list(edge_attr_list[j].values())[2]
            NiceCX_To.set_edge_attribute(edge_id, edge_attr_name, edge_attr_value )         
            
#create a dict to store the edge in To network, source node is key and target node as value
to_edge_map = dict(zip(to_edge_s_list,to_edge_t_list))         


print("\n","The From network is:")
NiceCX_From.print_summary()
print("\n","The To network is:")
NiceCX_To.print_summary()
# Out:
#  The From network is:
# Name: ChEMBL - High Affinity Compounds vs human targets (Commercially available)
# Nodes: 3564
# Edges: 11564
# Node Attributes: 13569
# Edge Attributes: 57820
#
#
#  The To network is:
# Name: Untitled
# Nodes: 10961
# Edges: 56553
# Node Attributes: 10961
# Edge Attributes: 169659

# %%
#Step 1: for each node in TO, store the id as the value and the name as the key in the name-id map

#create two arrays to store the node names and node ids in To network 
to_name_as_key = []
to_id_as_value = []

#following code is in "NiceCX v2.0 Tutorial", In[24], "CREATE A NAME to ID LOOKUP "

#NiceCX_To.get_nodes() returns two arguments: node_id (which is node id) and node (which is node object)
for node_id, node in NiceCX_To.get_nodes() :
    
    #creates a dict name_id_map, where to_node.get('n') is key and to_node.get('@id') is value
    name_id_map ={node.get('n'): node.get('@id') for node_id, node in NiceCX_To.get_nodes()}

to_name_as_key = list(name_id_map.keys()) # 
to_id_as_value = list(name_id_map.values()) # to_id_as_value[0] = 826, to_id_as_value[825] = 1


number_of_node_in_to = len(to_id_as_value)
print("number of nodes in To: ",number_of_node_in_to)
# Out:
# number of nodes in To:  10961

# %%
#add attribute "fromNetwork" to each node in NiceCX_To
for node_id, node in NiceCX_To.get_nodes() :
    NiceCX_To.add_node_attribute(node_id, name='fromNetwork', values='network1')
    print(NiceCX_To.get_node_attributes(node_id))   

#add attribute "fromNetwork" to each node in NiceCX_From
#for node_id, node in NiceCX_From.get_nodes() :
#    NiceCX_From.add_node_attribute(node_id, name='fromNetwork', values='network2')
#    print(NiceCX_From.get_node_attributes(node_id))
# Out:
# [{'po': 0, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 1, 'n': 'Secondary ID', 'v': 'uniprotKB:P00813'}, {'po': 1, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 2, 'n': 'Secondary ID', 'v': 'uniprotKB:A5A3E0'}, {'po': 2, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 3, 'n': 'Secondary ID', 'v': 'uniprotKB:Q562R1'}, {'po': 3, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 4, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8N7W2'}, {'po': 4, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 5, 'n': 'Secondary ID', 'v': 'uniprotKB:Q07021'}, {'po': 5, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 6, 'n': 'Secondary ID', 'v': 'uniprotKB:O75096'}, {'po': 6, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 7, 'n': 'Secondary ID', 'v': 'uniprotKB:Q6ZMN8'}, {'po': 7, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 8, 'n': 'Secondary ID', 'v': 'uniprotKB:P11142'}, {'po': 8, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 9, 'n': 'Secondary ID', 'v': 'uniprotKB:Q659C4-2'}, {'po': 9, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10, 'n': 'Secondary ID', 'v': 'uniprotKB:Q00535'}, {'po': 10, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 11, 'n': 'Secondary ID', 'v': 'uniprotKB:P20138'}, {'po': 11, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 12, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8N1S5'}, {'po': 12, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 13, 'n': 'Secondary ID', 'v': 'uniprotKB:P40855'}, {'po': 13, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 14, 'n': 'Secondary ID', 'v': 'uniprotKB:P62158'}, {'po': 14, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 15, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9UBI1'}, {'po': 15, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 16, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8N8A2-2'}, {'po': 16, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 17, 'n': 'Secondary ID', 'v': 'uniprotKB:O15084-1'}, {'po': 17, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 18, 'n': 'Secondary ID', 'v': 'uniprotKB:P46531'}, {'po': 18, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 19, 'n': 'Secondary ID', 'v': 'uniprotKB:Q04721'}, {'po': 19, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 20, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9UM47'}, {'po': 20, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 21, 'n': 'Secondary ID', 'v': 'uniprotKB:O75170-2'}, {'po': 21, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 22, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9UPN7'}, {'po': 22, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 23, 'n': 'Secondary ID', 'v': 'uniprotKB:Q5H9R7-2'}, {'po': 23, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 24, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9NWT6'}, {'po': 24, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 25, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9Y4B5-2'}, {'po': 25, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 26, 'n': 'Secondary ID', 'v': 'uniprotKB:O00743-2'}, {'po': 26, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 27, 'n': 'Secondary ID', 'v': 'uniprotKB:P42773'}, {'po': 27, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 28, 'n': 'Secondary ID', 'v': 'uniprotKB:P55039'}, {'po': 28, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 29, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9H446'}, {'po': 29, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 30, 'n': 'Secondary ID', 'v': 'uniprotKB:Q17R55'}, {'po': 30, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 31, 'n': 'Secondary ID', 'v': 'uniprotKB:Q86Y07-3'}, {'po': 31, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 32, 'n': 'Secondary ID', 'v': 'uniprotKB:P27824'}, {'po': 32, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 33, 'n': 'Secondary ID', 'v': 'uniprotKB:P11021'}, {'po': 33, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 34, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8TCT7'}, {'po': 34, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po':
 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10942, 'n': 'Secondary ID', 'v': 'uniprotKB:Q5TC84'}, {'po': 10942, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10943, 'n': 'Secondary ID', 'v': 'uniprotKB:P42772'}, {'po': 10943, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10944, 'n': 'Secondary ID', 'v': 'uniprotKB:P42771'}, {'po': 10944, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10945, 'n': 'Secondary ID', 'v': 'uniprotKB:P52333-2'}, {'po': 10945, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10946, 'n': 'Secondary ID', 'v': 'uniprotKB:P55273'}, {'po': 10946, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10947, 'n': 'Secondary ID', 'v': 'uniprotKB:Q96B02-2'}, {'po': 10947, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10948, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8WUY9'}, {'po': 10948, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10949, 'n': 'Secondary ID', 'v': 'uniprotKB:O15165-2'}, {'po': 10949, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10950, 'n': 'Secondary ID', 'v': 'uniprotKB:Q6ZUJ4'}, {'po': 10950, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10951, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9BUT9'}, {'po': 10951, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10952, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8IV13'}, {'po': 10952, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10953, 'n': 'Secondary ID', 'v': 'uniprotKB:O75909-4'}, {'po': 10953, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10954, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8IVW4'}, {'po': 10954, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10955, 'n': 'Secondary ID', 'v': 'uniprotKB:O95395'}, {'po': 10955, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10956, 'n': 'Secondary ID', 'v': 'uniprotKB:Q12794-3'}, {'po': 10956, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10957, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9Y2I2-1'}, {'po': 10957, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10958, 'n': 'Secondary ID', 'v': 'uniprotKB:Q96IQ9'}, {'po': 10958, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10959, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8WTX7'}, {'po': 10959, 'n': 'fromNetwork', 'v': 'network1'}]
# [{'po': 10960, 'n': 'Secondary ID', 'v': 'uniprotKB:A6NHX0'}, {'po': 10960, 'n': 'fromNetwork', 'v': 'network1'}]

# %%
#Step 2: for each node in FROM, check if its name is already in the name-id map. 
#If it is, then store the TO id as the value and the from id as the key in the from-to-id-map. 
#Otherwise, create the node in the TO network and 
#then store the mapping between the node id in FROM to the id of the new node in TO.

#create two lists for from-to-id-map, this map keeps the duplicated nodes
#fromid_list_as_key is the list has all the matched node id in From network
#toid_list_as_value is the list has all the matched node id in To network
fromid_list_as_key = []
toid_list_as_value =[]

#create two lists for old-new-id-map, this map keeps unmatched nodes
#oldid_list_as_key is the list that has all the unmatched node id in From network
#newid_list_as_value is the list that has all the new node id in To network, which is created/copied for unmatched node 
oldid_list_as_key =[]
newid_list_as_value = []

#for loop to check each node in From network, from_node retruns a node object
for from_node_id, from_node in NiceCX_From.get_nodes():
    a = 0
    this_node_name = from_node.get('n') #from_node.get('n') retruns node name of from_node_id in From network
    
    for i in range(len(to_name_as_key)):  # to_name_as_key is the list of node names in To network
        if (this_node_name == to_name_as_key[i]):  #if found the match node
            fromid_list_as_key.append(from_node_id)   #add this node id to duplicate From id list
            toid_list_as_value.append(name_id_map[this_node_name]) # find dict value(id in To network) by dict key (name in To) in name_id_map
            break
        else:
            a += 1
    
    if (a == len(to_name_as_key)): #if no match then create a new node in To network
        # "create_node" return a new node id in To network, id always begins from "0"
        new_id_in_To = NiceCX_To.create_node(this_node_name,node_represents=from_node_id) 
        
        oldid_list_as_key.append(from_node_id) #add this unmatched node id in From network to the old_id_list
        newid_list_as_value.append(new_id_in_To) #add the new created id in To network to the new_id_list

#create two dicts
from_to_id_map = dict(zip(fromid_list_as_key,toid_list_as_value))      
old_new_id_map = dict(zip(oldid_list_as_key,newid_list_as_value))
            
print ("found ", len(oldid_list_as_key), " unmatched nodes in From network. will be copied to To network")
                                               
print ("found ", len(fromid_list_as_key), "matched nodes in From network. will change attribute value to 'both' in To network")
# Out:
# found  3167  unmatched nodes in From network. will be copied to To network
# found  397 matched nodes in From network. will change attribute value to 'both' in To network

# %%
#for the matched nodes in To network
#add all attributes in From to the same node in To
#combine the same attributes and change the value of the attribute 

#in from_to_id_map, go through each id 

print (len(fromid_list_as_key))

for x in range (len(fromid_list_as_key)):
    
    #for each pair of from_to_id_map, find value (node id in To network) by key (node id in From network
    from_node_id = fromid_list_as_key[x]    
    to_node_id = from_to_id_map[from_node_id]
    
    #in From network, find the node corresponding from_node_id, store this node's attributes (name:value) in dict from_attr_map
    from_node_attr_list = NiceCX_From.get_node_attributes(from_node_id) #return each node attrbutes in From as an array
    from_node_attr_name = []
    from_node_attr_value = []
    
    if (from_node_attr_list != None):    
        for y in range(len(from_node_attr_list)):         
            from_node_attr_name.append(list(from_node_attr_list[y].values())[1]) 
            from_node_attr_value.append(list(from_node_attr_list[y].values())[2])  
    from_attr_map = dict(zip(from_node_attr_name,from_node_attr_value)) #create a dict to store the attributes pair in From network
    
    #in To network, find the node corresponding to_node_id, store this node's attributes (name:value) in dict to_attr_map
    to_node_attr_list = NiceCX_To.get_node_attributes(to_node_id)  #return each node attrbutes in To as an array
    to_node_attr_name = []
    to_node_attr_value = []
    
    if (to_node_attr_list != None):    
        for z in range(len(to_node_attr_list)): 
            to_node_attr_name.append(list(to_node_attr_list[z].values())[1])
            to_node_attr_value.append(list(to_node_attr_list[z].values())[2])
    to_attr_map = dict(zip(to_node_attr_name,to_node_attr_value)) #create a dict to store the attributes pair in From network
    
    #go through the attribute list of the node in from_to_id_map
    for a in range (len(to_node_attr_name)):
        for b in range (len(from_node_attr_name)):       
                    
            #copy the rest attributes in From network node to To network node with the pair of from_to_id_map
            if (from_node_attr_name[b] != to_node_attr_name[a]):
                NiceCX_To.add_node_attribute(to_node_id, from_node_attr_name[b], from_attr_map[from_node_attr_name[b]] ) 
        
        
    #add attribure 'fromNetwork', value is 'both'
    NiceCX_To.remove_node_attribute(to_node_id,'fromNetwork' )
    NiceCX_To.add_node_attribute(to_node_id, name='fromNetwork', values='both')
    
    print(NiceCX_To.get_node_attributes(to_node_id), "\n")
# Out:
# 397
# [{'po': 5374, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9UKV5'}, {'po': 5374, 'n': 'Target Name', 'v': 'P-glycoprotein 1'}, {'po': 5374, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7531&target=P-glycoprotein+1&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5374, 'n': 'type', 'v': 'protein'}, {'po': 5374, 'n': 'Target Name', 'v': 'P-glycoprotein 1'}, {'po': 5374, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7531&target=P-glycoprotein+1&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5374, 'n': 'type', 'v': 'protein'}, {'po': 5374, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 4305, 'n': 'Secondary ID', 'v': 'uniprotKB:Q86WN2'}, {'po': 4305, 'n': 'Target Name', 'v': 'Multidrug resistance-associated protein 1'}, {'po': 4305, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=8500&target=Multidrug+resistance-associated+protein+1&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4305, 'n': 'type', 'v': 'protein'}, {'po': 4305, 'n': 'Target Name', 'v': 'Multidrug resistance-associated protein 1'}, {'po': 4305, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=8500&target=Multidrug+resistance-associated+protein+1&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4305, 'n': 'type', 'v': 'protein'}, {'po': 4305, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7844, 'n': 'Secondary ID', 'v': 'uniprotKB:O95872'}, {'po': 7844, 'n': 'Target Name', 'v': 'Breakpoint cluster region protein /Tyrosine-protein kinase ABL'}, {'po': 7844, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50000271&target=Breakpoint+cluster+region+protein+%2FTyrosine-protein+kinase+ABL&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7844, 'n': 'type', 'v': 'protein'}, {'po': 7844, 'n': 'Target Name', 'v': 'Breakpoint cluster region protein /Tyrosine-protein kinase ABL'}, {'po': 7844, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50000271&target=Breakpoint+cluster+region+protein+%2FTyrosine-protein+kinase+ABL&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7844, 'n': 'type', 'v': 'protein'}, {'po': 7844, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7845, 'n': 'Secondary ID', 'v': 'uniprotKB:Q5W111'}, {'po': 7845, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase ABL'}, {'po': 7845, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50001306&target=Tyrosine-protein+kinase+ABL&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7845, 'n': 'type', 'v': 'protein'}, {'po': 7845, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase ABL'}, {'po': 7845, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50001306&target=Tyrosine-protein+kinase+ABL&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7845, 'n': 'type', 'v': 'protein'}, {'po': 7845, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 4781, 'n': 'Secondary ID', 'v': 'uniprotKB:O14735'}, {'po': 4781, 'n': 'Target Name', 'v': 'Acetyl-CoA carboxylase 1 (ACC1)'}, {'po': 4781, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5472&target=Acetyl-CoA+carboxylase+1+%28ACC1%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4781, 'n': 'type', 'v': 'protein'}, {'po': 4781, 'n': 'Target Name', 'v': 'Acetyl-CoA carboxylase 1 (ACC1)'}, {'po': 4781, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5472&target=Acetyl-CoA+carboxylase+1+%28ACC1%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4781, 'n': 'type', 'v': 'protein'}, {'po': 4781, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 6808, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9GZU1'}, {'po': 6808, 'n': 'Target Name', 'v': 'Acetyl-CoA carboxylase 2 (ACC2)'}, {'po': 6808, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5471&target=Acetyl-CoA+carboxylase+2+%28ACC2%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6808, 'n': 'type', 'v': 'protein'}, {'po': 6808, 'n': 'Target Name', 'v': 'Acetyl-CoA carboxylase 2 (ACC2)'}, {'po': 6808, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5471&target=Acetyl-CoA+carboxylase+2+%28ACC2%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6808, 'n': 'type', 'v': 'protein'}, {'po': 6808, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 2142, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9BRV8-2'}, {'po': 2142, 'n': 'Target Name', 'v': 'Angiotensin-Converting Enzyme 2'}, {'po': 2142, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50000018&target=Angiotensin-Converting+Enzyme+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2142, 'n': 'type', 'v': 'protein'}, {'po': 2142, 'n': 'Target Name', 'v': 'Angiotensin-Converting Enzyme 2'}, {'po': 2142, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50000018&target=Angiotensin-Converting+Enzyme+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2142, 'n': 'type', 'v': 'protein'}, {'po': 2142, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7595, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9Y297-2'}, {'po': 7595, 'n': 'Target Name', 'v': 'Prostatic acid phosphatase'}, {'po': 7595, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50000972&target=Prostatic+acid+phosphatase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7595, 'n': 'type', 'v': 'protein'}, {'po': 7595, 'n': 'Target Name', 'v': 'Prostatic acid phosphatase'}, {'po': 7595, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50000972&target=Prostatic+acid+phosphatase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7595, 'n': 'type', 'v': 'protein'}, {'po': 7595, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10960, 'n': 'Secondary ID', 'v': 'uniprotKB:A6NHX0'}, {'po': 10960, 'n': 'Target Name', 'v': 'Adenosine deaminase'}, {'po': 10960, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2318&target=Adenosine+deaminase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10960, 'n': 'type', 'v': 'protein'}, {'po': 10960, 'n': 'Target Name', 'v': 'Adenosine deaminase'}, {'po': 10960, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2318&target=Adenosine+deaminase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10960, 'n': 'type', 'v': 'protein'}, {'po': 10960, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 3362, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8WVH0'}, {'po': 3362, 'n': 'Target Name', 'v': 'Disintegrin and metalloproteinase domain-containing protein 10 (ADAM10)'}, {'po': 3362, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7603&target=Disintegrin+and+metalloproteinase+domain-containing+protein+10+%28ADAM10%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3362, 'n': 'type', 'v': 'protein'}, {'po': 3362, 'n': 'Target Name', 'v': 'Disintegrin and metalloproteinase domain-containing protein 10 (ADAM10)'}, {'po': 3362, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7603&target=Disintegrin+and+metalloproteinase+domain-containing+protein+10+%28ADAM10%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3362, 'n': 'type', 'v': 'protein'}, {'po': 3362, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7257, 'n': 'Secondary ID', 'v': 'uniprotKB:P48431'}, {'po': 7257, 'n': 'Target Name', 'v': 'ADAM17'}, {'po': 7257, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=110&target=ADAM17&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7257, 'n': 'type', 'v': 'protein'}, {'po': 7257, 'n': 'Target Name', 'v': 'ADAM17'}, {'po': 7257, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=110&target=ADAM17&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7257, 'n': 'type', 'v': 'protein'}, {'po': 7257, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10066, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8N3X1-2'}, {'po': 10066, 'n': 'Target Name', 'v': 'Disintegrin and metalloproteinase domain-containing protein 9 (ADAM9)'}, {'po': 10066, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7602&target=Disintegrin+and+metalloproteinase+domain-containing+protein+9+%28ADAM9%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10066, 'n': 'type', 'v': 'protein'}, {'po': 10066, 'n': 'Target Name', 'v': 'Disintegrin and metalloproteinase domain-containing protein 9 (ADAM9)'}, {'po': 10066, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7602&target=Disintegrin+and+metalloproteinase+domain-containing+protein+9+%28ADAM9%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10066, 'n': 'type', 'v': 'protein'}, {'po': 10066, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 107, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8NBT0'}, {'po': 107, 'n': 'Target Name', 'v': 'Adenosine kinase'}, {'po': 107, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50000448&target=Adenosine+kinase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 107, 'n': 'type', 'v': 'protein'}, {'po': 107, 'n': 'Target Name', 'v': 'Adenosine kinase'}, {'po': 107, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50000448&target=Adenosine+kinase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 107, 'n': 'type', 'v': 'protein'}, {'po': 107, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 5770, 'n': 'Secondary ID', 'v': 'uniprotKB:Q92871'}, {'po': 5770, 'n': 'Target Name', 'v': 'Adenosine receptor A3'}, {'po': 5770, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2135&target=Adenosine+receptor+A3&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5770, 'n': 'type', 'v': 'protein'}, {'po': 5770, 'n': 'Target Name', 'v': 'Adenosine receptor A3'}, {'po': 5770, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2135&target=Adenosine+receptor+A3&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5770, 'n': 'type', 'v': 'protein'}, {'po': 5770, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 3129, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9H0K1'}, {'po': 3129, 'n': 'Target Name', 'v': 'Angiotensin II receptor'}, {'po': 3129, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5550&target=Angiotensin+II+receptor&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 
 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3579&target=Beta+amyloid+A4+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8395, 'n': 'type', 'v': 'protein'}, {'po': 8395, 'n': 'Target Name', 'v': 'Beta amyloid A4 protein'}, {'po': 8395, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3579&target=Beta+amyloid+A4+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8395, 'n': 'type', 'v': 'protein'}, {'po': 8395, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 3610, 'n': 'Secondary ID', 'v': 'uniprotKB:Q96EK4'}, {'po': 3610, 'n': 'Target Name', 'v': 'Arginase-2, mitochondrial'}, {'po': 3610, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50004805&target=Arginase-2%2C+mitochondrial&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3610, 'n': 'type', 'v': 'protein'}, {'po': 3610, 'n': 'Target Name', 'v': 'Arginase-2, mitochondrial'}, {'po': 3610, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50004805&target=Arginase-2%2C+mitochondrial&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3610, 'n': 'type', 'v': 'protein'}, {'po': 3610, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 6095, 'n': 'Secondary ID', 'v': 'uniprotKB:UNKNOWN'}, {'po': 6095, 'n': 'Target Name', 'v': 'Serine-protein kinase ATM'}, {'po': 6095, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=10728&target=Serine-protein+kinase+ATM&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6095, 'n': 'type', 'v': 'protein'}, {'po': 6095, 'n': 'Target Name', 'v': 'Serine-protein kinase ATM'}, {'po': 6095, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=10728&target=Serine-protein+kinase+ATM&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6095, 'n': 'type', 'v': 'protein'}, {'po': 6095, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10220, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9BTT0'}, {'po': 10220, 'n': 'Target Name', 'v': 'Serine/threonine-protein kinase ATR'}, {'po': 10220, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5446&target=Serine%2Fthreonine-protein+kinase+ATR&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10220, 'n': 'type', 'v': 'protein'}, {'po': 10220, 'n': 'Target Name', 'v': 'Serine/threonine-protein kinase ATR'}, {'po': 10220, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5446&target=Serine%2Fthreonine-protein+kinase+ATR&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10220, 'n': 'type', 'v': 'protein'}, {'po': 10220, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 8495, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8TF01'}, {'po': 8495, 'n': 'Target Name', 'v': 'Serine/threonine-protein kinase Aurora'}, {'po': 8495, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1325&target=Serine%2Fthreonine-protein+kinase+Aurora&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8495, 'n': 'type', 'v': 'protein'}, {'po': 8495, 'n': 'Target Name', 'v': 'Serine/threonine-protein kinase Aurora'}, {'po': 8495, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1325&target=Serine%2Fthreonine-protein+kinase+Aurora&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8495, 'n': 'type', 'v': 'protein'}, {'po': 8495, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 6740, 'n': 'Secondary ID', 'v': 'uniprotKB:P58107'}, {'po': 6740, 'n': 'Target Name', 'v': 'Aurora kinase A-interacting protein'}, {'po': 6740, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50004344&target=Aurora+kinase+A-interacting+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6740, 'n': 'type', 'v': 'protein'}, {'po': 6740, 'n': 'Target Name', 'v': 'Aurora kinase A-interacting protein'}, {'po': 6740, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50004344&target=Aurora+kinase+A-interacting+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6740, 'n': 'type', 'v': 'protein'}, {'po': 6740, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 34, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8TCT7'}, {'po': 34, 'n': 'Target Name', 'v': 'Aurora kinase B/Inner centromere protein'}, {'po': 34, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=4981&target=Aurora+kinase+B%2FInner+centromere+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 34, 'n': 'type', 'v': 'protein'}, {'po': 34, 'n': 'Target Name', 'v': 'Aurora kinase B/Inner centromere protein'}, {'po': 34, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=4981&target=Aurora+kinase+B%2FInner+centromere+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 34, 'n': 'type', 'v': 'protein'}, {'po': 34, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 30, 'n': 'Secondary ID', 'v': 'uniprotKB:Q17R55'}, {'po': 30, 'n': 'Target Name', 'v': 'Serine/threonine-protein kinase Aurora-C'}, {'po': 30, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1402&target=Serine%2Fthreonine-protein+kinase+Aurora-C&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 30, 'n': 'type', 'v': 'protein'}, {'po': 30, 'n': 'Target Name', 'v': 'Serine/threonine-protein kinase Aurora-C'}, {'po': 30, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1402&target=Serine%2Fthreonine-protein+kinase+Aurora-C&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 30, 'n': 'type', 'v': 'protein'}, {'po': 30, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10055, 'n': 'Secondary ID', 'v': 'uniprotKB:E9PF47'}, {'po': 10055, 'n': 'Target Name', 'v': 'Beta-secretase 1'}, {'po': 10055, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5093&target=Beta-secretase+1&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10055, 'n': 'type', 'v': 'protein'}, {'po': 10055, 'n': 'Target Name', 'v': 'Beta-secretase 1'}, {'po': 10055, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5093&target=Beta-secretase+1&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10055, 'n': 'type', 'v': 'protein'}, {'po': 10055, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7316, 'n': 'Secondary ID', 'v': 'uniprotKB:Q96QT6'}, {'po': 7316, 'n': 'Target Name', 'v': 'Bcl2-antagonist of cell death (BAD)'}, {'po': 7316, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50000332&target=Bcl2-antagonist+of+cell+death+%28BAD%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7316, 'n': 'type', 'v': 'protein'}, {'po': 7316, 'n': 'Target Name', 'v': 'Bcl2-antagonist of cell death (BAD)'}, {'po': 7316, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50000332&target=Bcl2-antagonist+of+cell+death+%28BAD%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7316, 'n': 'type', 'v': 'protein'}, {'po': 7316, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10490, 'n': 'Secondary ID', 'v': 'uniprotKB:P55075-2'}, {'po': 10490, 'n': 'Target Name', 'v': 'Cholinesterase'}, {'po': 10490, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3620&target=Cholinesterase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10490, 'n': 'type', 'v': 'protein'}, {'po': 10490, 'n': 'Target Name', 'v': 'Cholinesterase'}, {'po': 10490, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3620&target=Cholinesterase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10490, 'n': 'type', 'v': 'protein'}, {'po': 10490, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 5683, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9NV92'}, {'po': 5683, 'n': 'Target Name', 'v': 'Apoptosis regulator Bcl-2'}, {'po': 5683, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3928&target=Apoptosis+regulator+Bcl-2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5683, 'n': 'type', 'v': 'protein'}, {'po': 5683, 'n': 'Target Name', 'v': 'Apoptosis regulator Bcl-2'}, {'po': 5683, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3928&target=Apoptosis+regulator+Bcl-2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5683, 'n': 'type', 'v': 'protein'}, {'po': 5683, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 5684, 'n': 'Secondary ID', 'v': 'uniprotKB:O95166'}, {'po': 5684, 'n': 'Target Name', 'v': 'Bcl-xL/BAK'}, {'po': 5684, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3744&target=Bcl-xL%2FBAK&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5684, 'n': 'type', 'v': 'protein'}, {'po': 5684, 'n': 'Target Name', 'v': 'Bcl-xL/BAK'}, {'po': 5684, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3744&target=Bcl-xL%2FBAK&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5684, 'n': 'type', 'v': 'protein'}, {'po': 5684, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 9935, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9H6X5-2'}, {'po': 9935, 'n': 'Target Name', 'v': 'Baculoviral IAP repeat-containing protein 2'}, {'po': 9935, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6600&target=Baculoviral+IAP+repeat-containing+protein+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 9935, 'n': 'type', 'v': 'protein'}, {'po': 9935, 'n': 'Target Name', 'v': 'Baculoviral IAP repeat-containing protein 2'}, {'po': 9935, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6600&target=Baculoviral+IAP+repeat-containing+protein+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 9935, 'n': 'type', 'v': 'protein'}, {'po': 9935, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10074, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8N4F0'}, {'po': 10074, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase Blk'}, {'po': 10074, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5620&target=Tyrosine-protein+kinase+Blk&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10074, 'n': 'type', 'v': 'protein'}, {'po': 10074, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase Blk'}, {'po': 10074, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5620&target=Tyrosine-protein+kinase+Blk&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10074, 'n': 'type', 'v': 'protein'}, {'po': 10074, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 2451, 'n': 'Secondary ID', 'v': 'uniprotKB:Q86UT6-2'}, {'po': 2451, 'n': 'Target Name', 'v': 'Bone morphogenetic protein 4'}, {'po': 2451, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50003902&target=Bone+morphogenetic+protein+4&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2451, 'n': 'type', 'v': 'protein'}, {'po': 2451, 'n': 'Target Name', 'v': 'Bone morphogenetic protein 4'}, {'po': 2451, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50003902&target=Bone+morphogenetic+protein+4&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2451, 'n': 'type', 'v': 'protein'}, {'po': 2451, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 852, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9NQZ2'}, {'po': 852, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase BMX'}, {'po': 852, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2712&target=Tyrosine-protein+kinase+BMX&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 852, 'n': 'type', 'v': 'protein'}, {'po': 852, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase BMX'}, {'po': 852, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2712&target=Tyrosine-protein+kinase+BMX&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 852, 'n': 'type', 'v': 'protein'}, {'po': 852, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 3267, 'n': 'Secondary ID', 'v': 'uniprotKB:P16157-10'}, {'po': 3267, 'n': 'Target Name', 'v': 'RAF serine/threonine protein kinase'}, {'po': 3267, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2857&target=RAF+serine%2Fthreonine+protein+kinase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3267, 'n': 'type', 'v': 'protein'}, {'po': 3267, 'n': 'Target Name', 'v': 'RAF serine/threonine protein kinase'}, {'po': 3267, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=2857&target=RAF+serine%2Fthreonine+protein+kinase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3267, 'n': 'type', 'v': 'protein'}, {'po': 3267, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 9565, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9ULT0'}, {'po': 9565, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 2'}, {'po': 9565, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6886&target=Bromodomain-containing+protein+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 9565, 'n': 'type', 'v': 'protein'}, {'po': 9565, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 2'}, {'po': 9565, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6886&target=Bromodomain-containing+protein+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 9565, 'n': 'type', 'v': 'protein'}, {'po': 9565, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 2468, 'n': 'Secondary ID', 'v': 'uniprotKB:Q86UK7-2'}, {'po': 2468, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 3'}, {'po': 2468, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6887&target=Bromodomain-containing+protein+3&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2468, 'n': 'type', 'v': 'protein'}, {'po': 2468, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 3'}, {'po': 2468, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6887&target=Bromodomain-containing+protein+3&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2468, 'n': 'type', 'v': 'protein'}, {'po': 2468, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 2469, 'n': 'Secondary ID', 'v': 'uniprotKB:P78332'}, {'po': 2469, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 4'}, {'po': 2469, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6885&target=Bromodomain-containing+protein+4&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2469, 'n': 'type', 'v': 'protein'}, {'po': 2469, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 4'}, {'po': 2469, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6885&target=Bromodomain-containing+protein+4&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2469, 'n': 'type', 'v': 'protein'}, {'po': 2469, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 6389, 'n': 'Secondary ID', 'v': 'uniprotKB:UNKNOWN'}, {'po': 6389, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 7'}, {'po': 6389, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50006451&target=Bromodomain-containing+protein+7&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6389, 'n': 'type', 'v': 'protein'}, {'po': 6389, 'n': 'Target Name', 'v': 'Bromodomain-containing protein 7'}, {'po': 6389, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50006451&target=Bromodomain-containing+protein+7&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6389, 'n': 'type', 'v': 'protein'}, {'po': 6389, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7075, 'n': 'Secondary ID', 'v': 'uniprotKB:A6NGZ7'}, {'po': 7075, 'n': 'Target Name', 'v': 'Peregrin'}, {'po': 7075, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50006701&target=Peregrin&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7075, 'n': 'type', 'v': 'protein'}, {'po': 7075, 'n': 'Target Name', 'v': 'Peregrin'}, {'po': 7075, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50006701&target=Peregrin&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7075, 'n': 'type', 'v': 'protein'}, {'po': 7075, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7076, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9H461'}, {'po': 7076, 'n': 'Target Name', 'v': 'Bromodomain and PHD finger-containing protein 3'}, {'po': 7076, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50006702&target=Bromodomain+and+PHD+finger-containing+protein+3&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7076, 'n': 'type', 'v': 'protein'}, {'po': 7076, 'n': 'Target Name', 'v': 'Bromodomain and PHD finger-containing protein 3'}, {'po': 7076, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50006702&target=Bromodomain+and+PHD+finger-containing+protein+3&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7076, 'n': 'type', 'v': 'protein'}, {'po': 7076, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 943, 'n': 'Secondary ID', 'v': 'uniprotKB:Q92896-2'}, {'po': 943, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase BTK'}, {'po': 943, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1846&target=Tyrosine-protein+kinase+BTK&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 943, 'n': 'type', 'v': 'protein'}, {'po': 943, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase BTK'}, {'po': 943, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1846&target=Tyrosine-protein+kinase+BTK&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 943, 'n': 'type', 'v': 'protein'}, {'po': 943, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 505, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9BRR8'}, {'po': 505, 'n': 'Target Name', 'v': 'Carbonic anhydrase'}, {'po': 505, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1192&target=Carbonic+anhydrase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 505, 'n': 'type', 'v': 'protein'}, {'po': 505, 'n': 'Target Name', 'v': 'Carbonic anhydrase'}, {'po': 505, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1192&target=Carbonic+anhydrase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 505, 'n': 'type', 'v': 'protein'}, {'po': 505, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 2739, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9Y394-2'}, {'po': 2739, 'n': 'Target Name', 'v': 'Carbonic anhydrase 12'}, {'po': 2739, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1363&target=Carbonic+anhydrase+12&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2739, 'n': 'type', 'v': 'protein'}, {'po': 2739, 'n': 'Target Name', 'v': 'Carbonic anhydrase 12'}, {'po': 2739, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1363&target=Carbonic+anhydrase+12&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2739, 'n': 'type', 'v': 'protein'}, {'po': 2739, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 3417, 'n': 'Secondary ID', 'v': 'uniprotKB:O15145'}, {'po': 3417, 'n': 'Target Name', 'v': 'Carbonic Anhydrase XIV'}, {'po': 3417, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1365&target=Carbonic+Anhydrase+XIV&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3417, 'n': 'type', 'v': 'protein'}, {'po': 3417, 'n': 'Target Name', 'v': 'Carbonic Anhydrase XIV'}, {'po': 3417, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1365&target=Carbonic+Anhydrase+XIV&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3417, 'n': 'type', 'v': 'protein'}, {'po': 3417, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 4288, 'n': 'Secondary ID', 'v': 'uniprotKB:P31371'}, {'po': 4288, 'n': 'Target Name', 'v': 'Carbonic anhydrase 4'}, {'po': 4288, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1247&target=Carbonic+anhydrase+4&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4288, 'n': 'type', 'v': 'protein'}, {'po': 4288, 'n': 'Target Name', 'v': 'Carbonic anhydrase 4'}, {'po': 4288, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1247&target=Carbonic+anhydrase+4&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4288, 'n': 'type', 'v': 'protein'}, {'po': 4288, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 374, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8N6M8-2'}, {'po': 374, 'n': 'Target Name', 'v': 'Carbonic anhydrase 6 (CA-VI)'}, {'po': 374, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=10154&target=Carbonic+anhydrase+6+%28CA-VI%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 374, 'n': 'type', 'v': 'protein'}, {'po': 374, 'n': 'Target Name', 'v': 'Carbonic anhydrase 6 (CA-VI)'}, {'po': 374, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=10154&target=Carbonic+anhydrase+6+%28CA-VI%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 374, 'n': 'type', 'v': 'protein'}, {'po': 374, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 4715, 'n': 'Secondary ID', 'v': 'uniprotKB:Q58WW2-2'}, {'po': 4715, 'n': 'Target Name', 'v': 'CaM kinase II'}, {'po': 4715, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50000812&target=CaM+kinase+II&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4715, 'n': 'type', 'v': 'protein'}, {'po': 4715, 'n': 'Target Name', 'v': 'CaM kinase II'}, {'po': 4715, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50000812&target=CaM+kinase+II&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4715, 'n': 'type', 'v': 'protein'}, {'po': 4715, 'n': 'fromNetwork', 'v': 'both'}]
#
# ...
#
# [{'po': 1654, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9NYS0'}, {'po': 1654, 'n': 'Target Name', 'v': 'Thyroid hormone receptor'}, {'po': 1654, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1951&target=Thyroid+hormone+receptor&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 1654, 'n': 'type', 'v': 'protein'}, {'po': 1654, 'n': 'Target Name', 'v': 'Thyroid hormone receptor'}, {'po': 1654, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1951&target=Thyroid+hormone+receptor&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 1654, 'n': 'type', 'v': 'protein'}, {'po': 1654, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 1821, 'n': 'Secondary ID', 'v': 'uniprotKB:Q96RG2-2'}, {'po': 1821, 'n': 'Target Name', 'v': 'Thyroid hormone receptor'}, {'po': 1821, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1952&target=Thyroid+hormone+receptor&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 1821, 'n': 'type', 'v': 'protein'}, {'po': 1821, 'n': 'Target Name', 'v': 'Thyroid hormone receptor'}, {'po': 1821, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1952&target=Thyroid+hormone+receptor&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 1821, 'n': 'type', 'v': 'protein'}, {'po': 1821, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7060, 'n': 'Secondary ID', 'v': 'uniprotKB:Q6URK8-2'}, {'po': 7060, 'n': 'Target Name', 'v': 'TRAF2 and NCK-interacting protein kinase (TNIK)'}, {'po': 7060, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7571&target=TRAF2+and+NCK-interacting+protein+kinase+%28TNIK%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7060, 'n': 'type', 'v': 'protein'}, {'po': 7060, 'n': 'Target Name', 'v': 'TRAF2 and NCK-interacting protein kinase (TNIK)'}, {'po': 7060, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7571&target=TRAF2+and+NCK-interacting+protein+kinase+%28TNIK%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7060, 'n': 'type', 'v': 'protein'}, {'po': 7060, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 6334, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9UI30'}, {'po': 6334, 'n': 'Target Name', 'v': 'Tyrosine kinase non-receptor protein 2'}, {'po': 6334, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5516&target=Tyrosine+kinase+non-receptor+protein+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6334, 'n': 'type', 'v': 'protein'}, {'po': 6334, 'n': 'Target Name', 'v': 'Tyrosine kinase non-receptor protein 2'}, {'po': 6334, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5516&target=Tyrosine+kinase+non-receptor+protein+2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6334, 'n': 'type', 'v': 'protein'}, {'po': 6334, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7243, 'n': 'Secondary ID', 'v': 'uniprotKB:Q92781'}, {'po': 7243, 'n': 'Target Name', 'v': 'Human diphtheria toxin-like ADP-ribosyltransferase (ARTD5 or PARP5a)'}, {'po': 7243, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7859&target=Human+diphtheria+toxin-like+ADP-ribosyltransferase+%28ARTD5+or+PARP5a%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7243, 'n': 'type', 'v': 'protein'}, {'po': 7243, 'n': 'Target Name', 'v': 'Human diphtheria toxin-like ADP-ribosyltransferase (ARTD5 or PARP5a)'}, {'po': 7243, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7859&target=Human+diphtheria+toxin-like+ADP-ribosyltransferase+%28ARTD5+or+PARP5a%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7243, 'n': 'type', 'v': 'protein'}, {'po': 7243, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 9469, 'n': 'Secondary ID', 'v': 'uniprotKB:P23416-2'}, {'po': 9469, 'n': 'Target Name', 'v': 'Human diphtheria toxin-like ADP-ribosyltransferase (ARTD6 or PARP5b)'}, {'po': 9469, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7858&target=Human+diphtheria+toxin-like+ADP-ribosyltransferase+%28ARTD6+or+PARP5b%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 9469, 'n': 'type', 'v': 'protein'}, {'po': 9469, 'n': 'Target Name', 'v': 'Human diphtheria toxin-like ADP-ribosyltransferase (ARTD6 or PARP5b)'}, {'po': 9469, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=7858&target=Human+diphtheria+toxin-like+ADP-ribosyltransferase+%28ARTD6+or+PARP5b%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 9469, 'n': 'type', 'v': 'protein'}, {'po': 9469, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 3097, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9BRR0'}, {'po': 3097, 'n': 'Target Name', 'v': 'DNA topoisomerase II'}, {'po': 3097, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50006129&target=DNA+topoisomerase+II&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3097, 'n': 'type', 'v': 'protein'}, {'po': 3097, 'n': 'Target Name', 'v': 'DNA topoisomerase II'}, {'po': 3097, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=com&complexid=50006129&target=DNA+topoisomerase+II&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 3097, 'n': 'type', 'v': 'protein'}, {'po': 3097, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 8917, 'n': 'Secondary ID', 'v': 'uniprotKB:Q8N9I0'}, {'po': 8917, 'n': 'Target Name', 'v': 'CREB-binding protein/p53'}, {'po': 8917, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3723&target=CREB-binding+protein%2Fp53&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8917, 'n': 'type', 'v': 'protein'}, {'po': 8917, 'n': 'Target Name', 'v': 'CREB-binding protein/p53'}, {'po': 8917, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=3723&target=CREB-binding+protein%2Fp53&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8917, 'n': 'type', 'v': 'protein'}, {'po': 8917, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 829, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9NW13'}, {'po': 829, 'n': 'Target Name', 'v': 'Transient receptor potential cation channel subfamily M member 8 (TRPM8)'}, {'po': 829, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6944&target=Transient+receptor+potential+cation+channel+subfamily+M+member+8+%28TRPM8%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 829, 'n': 'type', 'v': 'protein'}, {'po': 829, 'n': 'Target Name', 'v': 'Transient receptor potential cation channel subfamily M member 8 (TRPM8)'}, {'po': 829, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6944&target=Transient+receptor+potential+cation+channel+subfamily+M+member+8+%28TRPM8%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 829, 'n': 'type', 'v': 'protein'}, {'po': 829, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 7224, 'n': 'Secondary ID', 'v': 'uniprotKB:P13807'}, {'po': 7224, 'n': 'Target Name', 'v': 'Translocator protein'}, {'po': 7224, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5514&target=Translocator+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7224, 'n': 'type', 'v': 'protein'}, {'po': 7224, 'n': 'Target Name', 'v': 'Translocator protein'}, {'po': 7224, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5514&target=Translocator+protein&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 7224, 'n': 'type', 'v': 'protein'}, {'po': 7224, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 6920, 'n': 'Secondary ID', 'v': 'uniprotKB:O60688'}, {'po': 6920, 'n': 'Target Name', 'v': 'Dual specificity protein kinase TTK'}, {'po': 6920, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6217&target=Dual+specificity+protein+kinase+TTK&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6920, 'n': 'type', 'v': 'protein'}, {'po': 6920, 'n': 'Target Name', 'v': 'Dual specificity protein kinase TTK'}, {'po': 6920, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6217&target=Dual+specificity+protein+kinase+TTK&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 6920, 'n': 'type', 'v': 'protein'}, {'po': 6920, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 8137, 'n': 'Secondary ID', 'v': 'uniprotKB:Q06609'}, {'po': 8137, 'n': 'Target Name', 'v': 'Non-receptor tyrosine-protein kinase TYK2'}, {'po': 8137, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=4916&target=Non-receptor+tyrosine-protein+kinase+TYK2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8137, 'n': 'type', 'v': 'protein'}, {'po': 8137, 'n': 'Target Name', 'v': 'Non-receptor tyrosine-protein kinase TYK2'}, {'po': 8137, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=4916&target=Non-receptor+tyrosine-protein+kinase+TYK2&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 8137, 'n': 'type', 'v': 'protein'}, {'po': 8137, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10495, 'n': 'Secondary ID', 'v': 'uniprotKB:Q5U5X8'}, {'po': 10495, 'n': 'Target Name', 'v': 'Thymidylate synthase'}, {'po': 10495, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1936&target=Thymidylate+synthase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10495, 'n': 'type', 'v': 'protein'}, {'po': 10495, 'n': 'Target Name', 'v': 'Thymidylate synthase'}, {'po': 10495, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=1936&target=Thymidylate+synthase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10495, 'n': 'type', 'v': 'protein'}, {'po': 10495, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 4605, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9NZT1'}, {'po': 4605, 'n': 'Target Name', 'v': 'WD repeat-containing protein 5 (WDR5)'}, {'po': 4605, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=8469&target=WD+repeat-containing+protein+5+%28WDR5%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4605, 'n': 'type', 'v': 'protein'}, {'po': 4605, 'n': 'Target Name', 'v': 'WD repeat-containing protein 5 (WDR5)'}, {'po': 4605, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=8469&target=WD+repeat-containing+protein+5+%28WDR5%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 4605, 'n': 'type', 'v': 'protein'}, {'po': 4605, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 2113, 'n': 'Secondary ID', 'v': 'uniprotKB:Q9Y6Y8-2'}, {'po': 2113, 'n': 'Target Name', 'v': 'Protein Wnt-3a'}, {'po': 2113, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50004930&target=Protein+Wnt-3a&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2113, 'n': 'type', 'v': 'protein'}, {'po': 2113, 'n': 'Target Name', 'v': 'Protein Wnt-3a'}, {'po': 2113, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=50004930&target=Protein+Wnt-3a&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 2113, 'n': 'type', 'v': 'protein'}, {'po': 2113, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 774, 'n': 'Secondary ID', 'v': 'uniprotKB:P05204'}, {'po': 774, 'n': 'Target Name', 'v': 'Xanthine oxidase'}, {'po': 774, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5030&target=Xanthine+oxidase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 774, 'n': 'type', 'v': 'protein'}, {'po': 774, 'n': 'Target Name', 'v': 'Xanthine oxidase'}, {'po': 774, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5030&target=Xanthine+oxidase&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 774, 'n': 'type', 'v': 'protein'}, {'po': 774, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 5407, 'n': 'Secondary ID', 'v': 'uniprotKB:O95196-2'}, {'po': 5407, 'n': 'Target Name', 'v': 'X-linked inhibitor of apoptosis protein (XIAP)'}, {'po': 5407, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6599&target=X-linked+inhibitor+of+apoptosis+protein+%28XIAP%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5407, 'n': 'type', 'v': 'protein'}, {'po': 5407, 'n': 'Target Name', 'v': 'X-linked inhibitor of apoptosis protein (XIAP)'}, {'po': 5407, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=6599&target=X-linked+inhibitor+of+apoptosis+protein+%28XIAP%29&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 5407, 'n': 'type', 'v': 'protein'}, {'po': 5407, 'n': 'fromNetwork', 'v': 'both'}]
#
# [{'po': 10299, 'n': 'Secondary ID', 'v': 'uniprotKB:Q6UXN7'}, {'po': 10299, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase Yes'}, {'po': 10299, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5424&target=Tyrosine-protein+kinase+Yes&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10299, 'n': 'type', 'v': 'protein'}, {'po': 10299, 'n': 'Target Name', 'v': 'Tyrosine-protein kinase Yes'}, {'po': 10299, 'n': 'BindingDB Target Page', 'v': 'http://www.bindingdb.org/jsp/dbsearch/PrimarySearch_ki.jsp?energyterm=kJ/mole&tag=pol&polymerid=5424&target=Tyrosine-protein+kinase+Yes&column=ki&startPg=0&Increment=50&submit=Search'}, {'po': 10299, 'n': 'type', 'v': 'protein'}, {'po': 10299, 'n': 'fromNetwork', 'v': 'both'}]

# %%
#for the unmatched nodes, COPY the node attribute in From to the created node in To

#using for loop to retrieve all the unmatched node in From network
for n in range(len(oldid_list_as_key)):
    node_attributes = NiceCX_From.get_node_attributes(oldid_list_as_key[n])    #return node attributes as array  
    
    new_id_in_To = old_new_id_map[oldid_list_as_key[n]] #find the corrsponding node ids in To network
        
    #set the attribute values in the To network, have to set attributes one by one to each node
    if (node_attributes != None):
        for x in range(len(node_attributes)): 
            #print(node_attributes[x])
            attr_name = list(node_attributes[x].values())[1]   
            attr_value = list(node_attributes[x].values())[2]  
                
            NiceCX_To.set_node_attribute(new_id_in_To, attr_name, attr_value ) 
        
    #add attribute "fromNetwork" to each node in NiceCX_From
    NiceCX_To.add_node_attribute(new_id_in_To, name='fromNetwork', values='network2')

# %%
#check how many nodes in To network has "both" value
b = 0
n1 =0
n2=0
for id, node in NiceCX_To.get_nodes() :
    if (NiceCX_To.get_node_attribute_value(id, 'fromNetwork') == 'both'):
        b +=1        
    if (NiceCX_To.get_node_attribute_value(id, 'fromNetwork') == 'network1'):
        n1 += 1
    if (NiceCX_To.get_node_attribute_value(id, 'fromNetwork') == 'network2'):
        n2 += 1
print("There are ", b, " nodes in To network have 'both' attribute value")
print("There are ", n1, " nodes in To network have 'network1' attribute value")
print("There are ", n2, " nodes in To network have 'network2' attribute value")
# Out:
# There are  397  nodes in To network have 'both' attribute value
# There are  10564  nodes in To network have 'network1' attribute value
# There are  3167  nodes in To network have 'network2' attribute value

# %%
#Step 3: copy the edges from FROM, 
#creating new edges using the corresponding node ids in the from-to-node-id map and old_new_id_map.

#create 3 list to store each edge values in From network
from_edge_s_list = []
from_edge_t_list = []
#from_edge_i_list = []

#get each edge data in From network
for edge_id, from_edge in NiceCX_From.get_edges():
    from_edge_id = edge_id #edge id in From network
    from_edge_s = from_edge.get('s') #source node id in From network
    from_edge_t = from_edge.get('t') #target node id in From network
    from_edge_i = from_edge.get('i') #interaction in the From network

   #check if this edge is already in To network  
    for n in range (len(to_edge_s_list)):
        if (from_edge_s == to_edge_s_list[n] and from_edge_t == to_edge_map[to_edge_s_list[n]]):
            break

    # 'create_edge' creates an empty edge and returns an edge id
    NiceCX_To.create_edge(from_edge_s, from_edge_t, from_edge_i)    
    
    #set the edge attribute values      
    edge_attr_list = NiceCX_To.get_edge_attributes(from_edge_id)
    if(edge_attr_list != None):
        for x in range(len(edge_attr_list)): 
            edge_attr_name = list(edge_attr_list[x].values())[1] 
            edge_attr_value = list(edge_attr_list[x].values())[2]
            NiceCX_To.set_edge_attribute(edge_id, edge_attr_name, edge_attr_value )  
    
print("total nodes in the TO network ", len(NiceCX_To.get_nodes()))
print("total edges in the TO network ", len(NiceCX_To.get_edges()))
# Out:
# total nodes in the TO network  14128
# total edges in the TO network  68117

# %%
#upload the combined network to my account
uri_upload_message = NiceCX_To.upload_to("http://public.ndexbio.org", my_account, my_password)
print(uri_upload_message)
# Out:
# Generating CX
# http://public.ndexbio.org/v2/network/54c0250f-988d-11e9-bcaf-0ac135e8bacf

# %%
#update the network profile
uuid = uri_upload_message.rpartition('/')[-1]

new_profile={"name":"combined 2 networks", "description":"Merge 2 networks to make a new network in which nodes that have the same name are combined.", "version":"4.0"}
my_ndex.update_network_profile(uuid, new_profile)    
my_ndex.make_network_public(uuid)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-56-3e4dd7901048> in <module>()
#       3
#       4 new_profile={"name":"combined 2 networks", "description":"Merge 2 networks to make a new network in which nodes that have the same name are combined.", "version":"4.0"}
# ----> 5 my_ndex.update_network_profile(uuid, new_profile)
#       6 my_ndex.make_network_public(uuid)
#
# ~\Anaconda3\lib\site-packages\ndex2\client.py in update_network_profile(self, network_id, network_profile)
#     781         if self.version == "2.0":
#     782             route = "/network/%s/profile" % network_id
# --> 783             return self.put(route, json_data)
#     784         else:
#     785             route = "/network/%s/summary" % network_id
#
# ~\Anaconda3\lib\site-packages\ndex2\client.py in put(self, route, put_json)
#     131             response = self.s.put(url, headers=headers)
#     132         self.debug_response(response)
# --> 133         response.raise_for_status()
#     134         if response.status_code == 204:
#     135             return ""
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     937
#     938         if http_error_msg:
# --> 939             raise HTTPError(http_error_msg, response=self)
#     940
#     941     def close(self):
#
# HTTPError: 500 Server Error:  for url: http://public.ndexbio.org/v2/network/54c0250f-988d-11e9-bcaf-0ac135e8bacf/profile
